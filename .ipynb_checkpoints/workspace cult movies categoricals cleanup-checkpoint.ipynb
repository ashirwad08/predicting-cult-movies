# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from pprint import pprint
import pickle
import re
# %matplotlib inline

# %%
with open(r"movie_DF_0427.p", "rb") as input_file:
    mov = pickle.load(input_file)

# %%
mov.head()
# Out:
#     Unnamed: 0                    director      distributor     genre_bomojo  \
# 1          890             Peter Masterson  Island Pictures            Drama
# 3          240                 Peter Yates              Fox   Comedy / Drama
# 6         3773               Jeffrey Blitz        ThinkFilm      Documentary
# 7         4000  Zana Briski, Ross Kauffman        ThinkFilm      Documentary
# 13         428               Albert Brooks         Columbia  Romantic Comedy
#
#    rating                  title releaseDate  isCult        canontitle  \
# 1      PG  The Trip to Bountiful  1985-12-20       0   triptobountiful
# 3      PG          Breaking Away  1979-07-13       0      breakingaway
# 6       G             Spellbound  2003-04-30       0        spellbound
# 7       R     Born into Brothels  2004-12-08       0  bornintobrothels
# 13      R         Modern Romance  1981-03-13       0     modernromance
#
#     rev_totalGross            ...             releaseYear  Year AvgPrice  \
# 1   18365865.06860            ...                    1985  1985      3.5
# 3   56370318.57600            ...                    1979  1979      2.5
# 6    8191870.83000            ...                    2003  2003      6.0
# 7    4864390.86774            ...                    2004  2004      6.2
# 13   9100017.91111            ...                    1981  1981      2.7
#
#     rev_opening_ADJ  rev_totalGross_ADJ  year    CPI  prod_budget_ADJ  \
# 1      20560.131429        4.502261e+07  1985  107.6   5650869.561865
# 3      60753.264000        1.934629e+08  1979   72.6  24281886.199245
# 6      25036.440000        1.171438e+07  2003  184.0   1470292.595044
# 7      20211.435484        6.731689e+06  2004  188.9    844906.581073
# 13     57915.000000        2.891783e+07  1981   90.9   3629530.152339
#
#     CULT_INDEX  is_missing_prodbudgetADJ
# 1     1.558343                         1
# 3     1.541993                         1
# 6     1.494456                         1
# 7     1.486565                         1
# 13    1.479403                         1
#
# [5 rows x 27 columns]

# %%
mov.columns
# Out:
# Index([              u'Unnamed: 0',                 u'director',
#                     u'distributor',             u'genre_bomojo',
#                          u'rating',                    u'title',
#                     u'releaseDate',                   u'isCult',
#                      u'canontitle',           u'rev_totalGross',
#                     u'rev_opening',             u'num_theaters',
#                         u'runtime',              u'prod_budget',
#                 u'rev_postOpening',                u'leadActor',
#                    u'runtime_mins',              u'releaseYear',
#                            u'Year',                 u'AvgPrice',
#                 u'rev_opening_ADJ',       u'rev_totalGross_ADJ',
#                            u'year',                      u'CPI',
#                 u'prod_budget_ADJ',               u'CULT_INDEX',
#        u'is_missing_prodbudgetADJ'],
#       dtype='object')

# %%
mov.drop(['Unnamed: 0','rev_opening','rev_postOpening','runtime','Year','year','rev_totalGross','prod_budget','AvgPrice','CPI'], axis=1, inplace=True)

# %%
mov.shape
# Out:
# (5229, 17)

# %%
mov.columns
# Out:
# Index([u'director', u'distributor', u'genre_bomojo', u'rating', u'title',
#        u'releaseDate', u'isCult', u'canontitle', u'num_theaters', u'leadActor',
#        u'runtime_mins', u'releaseYear', u'rev_opening_ADJ',
#        u'rev_totalGross_ADJ', u'prod_budget_ADJ', u'CULT_INDEX',
#        u'is_missing_prodbudgetADJ'],
#       dtype='object')

# %%
#normalize genres
mov.genre_bomojo.value_counts()
# Out:
# Unknown               697
# Comedy                678
# Drama                 365
# Romantic Comedy       277
# Thriller              199
# Horror                195
# Comedy / Drama        191
# Action                159
# Animation             158
# Family Comedy         127
# Romance               119
# Action Comedy         115
# Crime Drama           105
# Drama / Thriller      103
# Family Adventure       89
# Period Drama           88
# Action Thriller        83
# Crime Comedy           80
# Music Drama            80
# Sports Drama           74
# Fantasy Comedy         56
# Sports Comedy          53
# Sci-Fi Action          52
# Horror Comedy          48
# Sci-Fi Horror          47
# Crime Thriller         47
# Horror Thriller        43
# Action Drama           43
# Action / Adventure     41
# Musical                41
#                      ...
# War                    36
# Romantic Thriller      35
# Fantasy                32
# Sci-Fi Comedy          31
# Period Comedy          29
# Action Horror          28
# Sci-Fi Thriller        28
# Fantasy Drama          27
# Family                 27
# Adventure              26
# Comedy Thriller        26
# Crime                  26
# War Drama              24
# Historical Drama       17
# Foreign                14
# Period Action          13
# Period Horror          11
# Historical Epic        11
# Sci-Fi                 10
# Adventure Comedy       10
# Sci-Fi Fantasy          9
# Action Fantasy          9
# Concert                 7
# Sports Action           7
# Western Comedy          6
# IMAX                    5
# Romantic Adventure      3
# War Romance             3
# Foreign / Action        2
# Foreign / Horror        2
# Name: genre_bomojo, dtype: int64

# %%
#mov=mov.loc[mov.genre_bomojo != "Documentary",:]

# %%
mov.genre_bomojo.astype('category')
genreGroups = ["Group %s" % g for g in mov.genre_bomojo.cat.categories]
len(genreGroups)
# Out:
# 64

# %%
mov['genre']=mov.genre_bomojo.str.extract(r'^(Adventure|Action|Comedy|Romance|Romantic|Fantasy|Drama|Crime|Horror|Music|Musical|Unknown|Foreign|Sci-Fi|Animation|Concert|Family|Historical|IMAX|Period|Sports|Thriller|War|Western)')

# %%
mov.genre.value_counts()
# Out:
# Comedy        895
# Unknown       697
# Action        516
# Drama         468
# Romantic      315
# Horror        286
# Crime         258
# Family        243
# Sci-Fi        215
# Thriller      199
# Period        178
# Animation     158
# Sports        134
# Music         121
# Romance       119
# Fantasy       115
# War            63
# Western        44
# Adventure      36
# Historical     28
# Foreign        18
# Concert         7
# IMAX            5
# Name: genre, dtype: int64

# %%
mov=mov[mov.genre!="IMAX"]

# %%
mov=mov[mov.genre!='Concert']

# %%
mov=mov[mov.genre!='Historical']

# %%
mov['genre']=mov.genre.str.replace(r'^Romance|Romantic','Romance')

# %%
mov.genre.value_counts()
# Out:
# Comedy       895
# Unknown      697
# Action       516
# Drama        468
# Romance      434
# Horror       286
# Crime        258
# Family       243
# Sci-Fi       215
# Thriller     199
# Period       178
# Animation    158
# Sports       134
# Music        121
# Fantasy      115
# War           63
# Western       44
# Adventure     36
# Foreign       18
# Name: genre, dtype: int64

# %%
cult = mov[mov.isCult==1]
nocultSample = mov[mov.isCult==0].sample(432)

movsample = pd.concat([cult, nocultSample])
#cult.isCult.sum()
movsample.shape
# Out:
# (864, 19)

# %%
#nocultSample.isCult.sum()
# Out:
# 0.0

# %%
plt.figure(figsize=(15, 8))
sns.set_style('whitegrid')


#sns.boxplot(x='genre',y='CULT_INDEX',data=mov.loc[~mov.genre.isin(['Foreign','Drama']),:])
sns.boxplot(x='genre',y='CULT_INDEX',data=movsample, hue='isCult')
plt.ylim(0,30)
plt.title('Variation in Cult Index by Genre')

# %%
pickle.dump(mov, open('movie_DF_0427.p', 'wb'))

# %%
mov.rating.value_counts()
# Out:
# R          2461
# PG-13      1422
# PG          994
# G           145
# Unrated      40
# NC-17        10
# GP            5
# M             1
# Name: rating, dtype: int64

# %%
mov.columns
# Out:
# Index([                u'director',              u'distributor',
#                    u'genre_bomojo',                   u'rating',
#                           u'title',              u'releaseDate',
#                          u'isCult',               u'canontitle',
#                    u'num_theaters',                u'leadActor',
#                    u'runtime_mins',              u'releaseYear',
#                 u'rev_opening_ADJ',       u'rev_totalGross_ADJ',
#                 u'prod_budget_ADJ',               u'CULT_INDEX',
#        u'is_missing_prodbudgetADJ',                    u'genre'],
#       dtype='object')

# %%
sns.regplot(x='runtime_mins',y='CULT_INDEX',data=mov)

# %%
mov.to_csv('./movie_df_apr27.csv',header=True,encoding='utf-8')

# %%
mov.sort_values(by='lifetimeRevenue', ascending=False).head(20)
# Out:
#                           director   distributor      genre_bomojo rating  \
# 4966              Steven Spielberg     Universal   Horror Thriller     PG
# 4967                Joseph Sargent     Universal   Horror Thriller     PG
# 5132              William Friedkin  Warner Bros.            Horror      R
# 5429                  Renny Harlin  Warner Bros.            Horror      R
# 5136               George Roy Hill     Universal      Crime Comedy     PG
# 3176                 James Cameron     Paramount           Romance  PG-13
# 3175              Robert Lieberman     Paramount           Romance  PG-13
# 746           Francis Ford Coppola     Paramount       Crime Drama      R
# 5114                 Arthur Hiller     Paramount           Romance     GP
# 5110                 George Seaton     Universal  Drama / Thriller      G
# 4550                 James Cameron           Fox  Sci-Fi Adventure  PG-13
# 5130                  George Lucas     Universal     Period Comedy     PG
# 5139                    Mel Brooks  Warner Bros.    Western Comedy      R
# 5148  John Guillermin, Irwin Allen           Fox   Action Thriller     PG
# 5115                 Robert Altman           Fox    Comedy / Drama      R
# 1655              Steven Spielberg     Paramount  Period Adventure     PG
# 4234              Steven Spielberg     Universal     Sci-Fi Horror  PG-13
# 1734                Randal Kleiser     Paramount           Musical     PG
# 4567                  George Lucas           Fox    Sci-Fi Fantasy     PG
# 4569                   Dave Filoni           Fox    Sci-Fi Fantasy     PG
#
#                                              title releaseDate  isCult  \
# 4966                                          Jaws  1975-06-20       0
# 4967                             Jaws: The Revenge  1975-06-20       0
# 5132                                  The Exorcist  1973-12-26       0
# 5429                       Exorcist: The Beginning  1973-12-26       0
# 5136                                     The Sting  1973-12-25       0
# 3176                                       Titanic  1997-12-19       0
# 3175                                       Titanic  1997-12-19       0
# 746                                  The Godfather  1972-03-15       0
# 5114                                    Love Story  1970-12-16       1
# 5110                                       Airport  1970-03-05       0
# 4550                                        Avatar  2009-12-18       0
# 5130                             American Graffiti  1973-08-01       0
# 5139                               Blazing Saddles  1974-02-07       1
# 5148                          The Towering Inferno  1974-12-14       0
# 5115                                       M"A*S*H  1970-01-25       0
# 1655                       Raiders of the Lost Ark  1981-06-12       0
# 4234                                 Jurassic Park  1993-06-11       0
# 1734                                        Grease  1978-06-16       0
# 4567  Star Wars: Episode I – The Phantom Menace 3D  1999-05-19       0
# 4569                     Star Wars: The Clone Wars  1999-05-19       0
#
# 5139    1.000345                         1  Western     2.416290e+08
# 5148    1.000333                         0   Action     2.345520e+08
# 5115    1.000348                         0   Comedy     2.222128e+08
# 1655    1.000583                         0   Period     2.176966e+08
# 4234    1.000239                         0   Sci-Fi     2.131748e+08
# 1734    1.000720                         0    Music     2.131136e+08
# 4567    1.000190                         0   Sci-Fi     2.115588e+08
# 4569    1.000190                         0   Sci-Fi     2.115588e+08

# %%
# trying a new approach to CULT_INDEX: Break down the total gross over the # of years. Here's how CI looks:
# ( total lifetime gross / time ) * ln(time). I want to add a weighting factor in favor of older movies so that I don't skew recent movies that result in 
# higher average gross.

mov['lifetimeRevenue'] = (mov.rev_totalGross_ADJ/(2016-mov.releaseYear)) * np.log(2016-mov.releaseYear)

mov['CULT_INDEX'] = mov.lifetimeRevenue/((mov.rev_opening_ADJ)*(mov.num_theaters)) #get it greater than 1
mov=mov.sort_values(by='CULT_INDEX',ascending=False)

# %%
mov.head(50)
# Out:
#                          director             distributor      genre_bomojo  \
# 3                     Peter Yates                     Fox    Comedy / Drama
# 1                 Peter Masterson         Island Pictures             Drama
# 56           Francis Ford Coppola                     MGM               War
# 26                Martin Scorsese            Warner Bros.           Unknown
# 13                  Albert Brooks                Columbia   Romantic Comedy
# 23                   Will Carroll                 Miramax           Romance
# 42                 Vadim Perelman              DreamWorks  Drama / Thriller
# 32                   Miranda July                     IFC    Comedy / Drama
# 40             Raymond De Felitta        Anchor Bay Films            Comedy
# 87                      Bob Fosse                     Fox           Musical
# 66                      Mira Nair               USA Films           Foreign
# 49                      Ed Harris           Sony Classics             Drama
# 84                Kimberly Peirce         Fox Searchlight             Drama
# 82                        Ang Lee          Focus Features           Foreign
# 137              Kevin Tancharoen                     MGM       Music Drama
# 138                   Alan Parker                     MGM       Music Drama
# 21                 Gavin O'Connor                 Miramax             Drama
# 75                Bruce Beresford               Universal           Unknown
# 113                   Woody Allen         Fox Searchlight    Fantasy Comedy
# 119                  Sidney Lumet               ThinkFilm    Crime Thriller
# 41   Fenton Bailey, Randy Barbato                  Strand   Comedy Thriller
# 120                  Sidney Lumet            Warner Bros.           Unknown
# 29                 Matthew Barney                    Palm           Unknown
# 155             Richard Linklater         Millennium Ent.    Comedy / Drama
# 52                   Julie Taymor         Fox Searchlight     Fantasy Drama
# 212                   Ken Russell            Warner Bros.     Sci-Fi Horror
# 141                Mike Birbiglia                     IFC            Comedy
# 107                   John Curran      Warner Independent      Period Drama
# 47                    Gregg Araki                  Tartan             Drama
# 211                 Walter Salles          Focus Features           Foreign
# 94                 Alison Maclean              Lions Gate             Drama
# 81                  Anton Corbijn       Weinstein Company       Music Drama
# 130                  Tom McCarthy                 Miramax             Drama
# 221               Kathryn Bigelow    Summit Entertainment               War
# 180               Aaron Schneider           Sony Classics            Comedy
# 112                   Danny Boyle      Paramount Classics      Period Drama
# 169               Julian Schnabel                 Miramax             Drama
# 53                     Lee Hirsch                 Artisan           Unknown
# 150              Darren Aronofsky                 Artisan             Drama
# 57                 Jonas Åkerlund               Newmarket       Crime Drama
# 143                    Ryan Fleck               ThinkFilm             Drama
# 106                  Miranda July    Roadside Attractions             Drama
# 23                 playingbyheart             1
# 42              houseofsandandfog             2
# 32      meandyouandeveryoneweknow             1
# 40                     cityisland             2
# 87                    allthatjazz             5
# 66                 monsoonwedding             2
# 49                        pollock             2
# 84                    boysdontcry             2
# 82                    lustcaution             1
# 137                          fame             3
# 138                          fame             3
# 21                        miracle             1
# 75                  tendermercies             3
# 113             melindaandmelinda             1
# 119  beforethedevilknowsyouredead             2
# 41                   partymonster             1
# 120               princeofthecity             3
# 29                 cremastercycle             1
# 155                        bernie             3
# 52                          titus             2
# 212                 alteredstates             3
# 141               sleepwalkwithme             1
# 107                   paintedveil             4
# 47                 mysteriousskin             1
# 211             motorcyclediaries             3
# 94                       jesusson             1
# 81                        control             1
# 130                  stationagent             3
# 221                    hurtlocker             4
# 180                        getlow             4
# 112                      sunshine             4
# 169     divingbellandthebutterfly             3
# 53                        amandla             1
# 150              requiemforadream             2
# 57                           spun             1
# 143                    halfnelson             2
# 106                        future             1
# 77                     compliance             1
# 287       beastsofthesouthernwild             4
# 209                      25thhour             5
# 135                  beyondthesea             6
# 144                     killerjoe             3
# 204                   wintersbone             4
# 134                       perfume             3
# 133                       perfume             3
#
#                                              leadActor  runtime_mins  \
# 3                                   Dennis Christopher           100
# 1                                       Geraldine Page           108
# 56                                        Martin Sheen           153
# 26                                       Griffin Dunne            96
# 13                                       Albert Brooks            93
# 23                                      Angelina Jolie           121
# 42                                   Jennifer Connelly           126
# 32                                        Miranda July            90
# 40                                         Andy García           100
# 87                                        Roy Scheider           123
# 66                                    Naseeruddin Shah           114
# 49                                           Ed Harris           117
# 84                                        Hilary Swank           118
# 82                                 Tony Leung Chiu-Wai           158
# 137                                       Debbie Allen           134
# 138                                         Irene Cara           134
# 21                                        Kurt Russell            96
# 75                                       Robert Duvall            92
# 113                                   Chiwetel Ejiofor           100
# 119                             Philip Seymour Hoffman           123
# 41                                          Seth Green            97
# 120                                     Treat Williams           167
# 29                                                 NaN           182
# 155                                         Jack Black           104
# 52                                     Anthony Hopkins           162
# 212                                       William Hurt           103
# 141                                     Mike Birbiglia            81
# 107                                        Naomi Watts           124
# 47                                Joseph Gordon-Levitt            99
# 211                                 Gael García Bernal           126
# 94                                        Billy Crudup           105
# 81                                           Sam Riley           121
# 130                                     Peter Dinklage            88
# 221                                      Jeremy Renner           130
# 180                                      Robert Duvall           100
# 112                                     Cillian Murphy           180
# 169                                    Mathieu Amalric           112
# 53   the use of music against South Africa under ap...           103
# 150                                      Ellen Burstyn           102
# 57                                   Jason Schwartzman           101
# 143                                       Ryan Gosling           107
# 106                                   Hamish Linklater            91
# 77                                            Ann Dowd            90
# 287                                  Quvenzhané Wallis            91
# 209                                      Edward Norton           134
# 135                                       Kevin Spacey           118
# 144                                Matthew McConaughey           103
# 204                                  Jennifer Lawrence           100
# 134                                     Estella Warren           147
# 133                                        Ben Whishaw           147
#
#      releaseYear  rev_opening_ADJ  rev_totalGross_ADJ  prod_budget_ADJ  \
# 3           1979     60753.264000        1.934629e+08     2.428189e+07
# 1           1985     20560.131429        4.502261e+07     5.650870e+06
# 56          1979    406891.056000        9.279672e+08     1.164709e+08
# 40    34.238985                         0    Comedy   2410499.871050
# 87    29.383502                         1     Music  43478463.164194
# 66    28.245162                         1   Foreign   5728164.417247
# 49    27.259627                         1     Drama   3904951.992678
# 84    22.385200                         0     Drama   5663613.081637
# 82    22.192952                         0   Foreign   1789849.958693
# 137   19.648220                         1     Music  22984173.629280
# 138   19.648220                         1     Music  22984173.629280
# 21    18.198494                         1     Drama    448948.515380
# 75    17.568827                         1   Unknown   6852907.779738
# 113   15.062440                         1   Fantasy   1499094.123808
# 119   14.777424                         1     Crime   2753475.128314
# 41    13.823421                         1    Comedy    299734.481123
# 120   13.508542                         1   Unknown   8333832.741851
# 29    13.462933                         1   Unknown    207632.754623
# 155   13.462166                         1    Comedy   3763648.018251
# 52    12.863815                         1   Fantasy    985088.037626
# 212   12.447351                         1    Sci-Fi  21521906.390179
# 141   12.397487                         1    Comedy    926378.793800
# 107   11.989167                         1    Period   3233886.944004
# 47    11.962109                         1     Drama    279439.532095
# 211   10.030039                         1   Foreign   6654997.272617
# 94     9.848387                         0     Drama    591318.733919
# 81     9.709131                         1     Music    339024.171251
# 130    9.341138                         1     Drama   2315646.141634
# 221    9.308366                         0       War   6191280.609589
# 180    8.546312                         0    Comedy   3315976.081246
# 112    8.533200                         1    Period   2501019.612635
# 169    8.140620                         1     Drama   2333315.439231
# 53     8.064444                         1   Unknown    163537.493664
# 150    7.872905                         1     Drama   1651012.285407
# 57     7.651381                         1     Crime    165872.757962
# 143    7.595119                         1     Drama   1082419.272425
# 106    7.325829                         0     Drama    215913.016236
# 77     7.316037                         1     Drama    130525.202114
# 287    7.095358                         1     Drama   5230960.843287
# 209    6.703199                         0     Crime   5397587.138933
# 135    6.667279                         1     Music   2505811.418421
# 144    6.580510                         1    Comedy    812606.407458
# 204    6.325484                         0     Drama   2360081.273623
# 134    6.074871                         0  Thriller    891990.546650
# 133    6.074871                         0  Thriller    891990.546650

# %%
plt.figure(figsize=(15, 8))
sns.set_style('whitegrid')

#sns.boxplot(x='genre',y='CULT_INDEX',data=mov.loc[~mov.genre.isin(['Foreign','Drama']),:])
sns.boxplot(x='isCult',y='CULT_INDEX',data=movsample)
plt.ylim(0,0.009)
plt.title('Variation in Cult Index')

# %%
plt.figure(figsize=(15, 8))
sns.set_style('whitegrid')

#sns.boxplot(x='genre',y='CULT_INDEX',data=mov.loc[~mov.genre.isin(['Foreign','Drama']),:])
sns.boxplot(x='rating',y='CULT_INDEX',data=movsample.loc[~movsample.rating.isin(['Unrated']),:], hue='isCult')
plt.ylim(0,0.02)
plt.title('Variation in Cult Index by Rating\n(EXCLUDING "Unrated")')

# %%
movsample.columns
# Out:
# Index([                u'director',              u'distributor',
#                    u'genre_bomojo',                   u'rating',
#                           u'title',              u'releaseDate',
#                          u'isCult',               u'canontitle',
#                    u'num_theaters',                u'leadActor',
#                    u'runtime_mins',              u'releaseYear',
#                 u'rev_opening_ADJ',       u'rev_totalGross_ADJ',
#                 u'prod_budget_ADJ',               u'CULT_INDEX',
#        u'is_missing_prodbudgetADJ',                    u'genre',
#                 u'lifetimeRevenue'],
#       dtype='object')

# %%
#SWITCHING TO CHECK OUT THE NUMERIC FEATURES
