# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from pprint import pprint
import pickle
import re
# %matplotlib inline

# %%
with open(r"movie_DF_0427.p", "rb") as input_file:
    mov = pickle.load(input_file)

# %%
mov.head()
# Out:
#     Unnamed: 0                    director      distributor     genre_bomojo  \
# 1          890             Peter Masterson  Island Pictures            Drama
# 3          240                 Peter Yates              Fox   Comedy / Drama
# 6         3773               Jeffrey Blitz        ThinkFilm      Documentary
# 7         4000  Zana Briski, Ross Kauffman        ThinkFilm      Documentary
# 13         428               Albert Brooks         Columbia  Romantic Comedy
#
#    rating                  title releaseDate  isCult        canontitle  \
# 1      PG  The Trip to Bountiful  1985-12-20       0   triptobountiful
# 3      PG          Breaking Away  1979-07-13       0      breakingaway
# 6       G             Spellbound  2003-04-30       0        spellbound
# 7       R     Born into Brothels  2004-12-08       0  bornintobrothels
# 13      R         Modern Romance  1981-03-13       0     modernromance
#
#     rev_totalGross            ...             releaseYear  Year AvgPrice  \
# 1   18365865.06860            ...                    1985  1985      3.5
# 3   56370318.57600            ...                    1979  1979      2.5
# 6    8191870.83000            ...                    2003  2003      6.0
# 7    4864390.86774            ...                    2004  2004      6.2
# 13   9100017.91111            ...                    1981  1981      2.7
#
#     rev_opening_ADJ  rev_totalGross_ADJ  year    CPI  prod_budget_ADJ  \
# 1      20560.131429        4.502261e+07  1985  107.6   5650869.561865
# 3      60753.264000        1.934629e+08  1979   72.6  24281886.199245
# 6      25036.440000        1.171438e+07  2003  184.0   1470292.595044
# 7      20211.435484        6.731689e+06  2004  188.9    844906.581073
# 13     57915.000000        2.891783e+07  1981   90.9   3629530.152339
#
#     CULT_INDEX  is_missing_prodbudgetADJ
# 1     1.558343                         1
# 3     1.541993                         1
# 6     1.494456                         1
# 7     1.486565                         1
# 13    1.479403                         1
#
# [5 rows x 27 columns]

# %%
mov.columns
# Out:
# Index([              u'Unnamed: 0',                 u'director',
#                     u'distributor',             u'genre_bomojo',
#                          u'rating',                    u'title',
#                     u'releaseDate',                   u'isCult',
#                      u'canontitle',           u'rev_totalGross',
#                     u'rev_opening',             u'num_theaters',
#                         u'runtime',              u'prod_budget',
#                 u'rev_postOpening',                u'leadActor',
#                    u'runtime_mins',              u'releaseYear',
#                            u'Year',                 u'AvgPrice',
#                 u'rev_opening_ADJ',       u'rev_totalGross_ADJ',
#                            u'year',                      u'CPI',
#                 u'prod_budget_ADJ',               u'CULT_INDEX',
#        u'is_missing_prodbudgetADJ'],
#       dtype='object')

# %%
mov.drop(['Unnamed: 0','rev_opening','rev_postOpening','runtime','Year','year','rev_totalGross','prod_budget','AvgPrice','CPI'], axis=1, inplace=True)

# %%
mov.shape
# Out:
# (5229, 17)

# %%
mov.columns
# Out:
# Index([u'director', u'distributor', u'genre_bomojo', u'rating', u'title',
#        u'releaseDate', u'isCult', u'canontitle', u'num_theaters', u'leadActor',
#        u'runtime_mins', u'releaseYear', u'rev_opening_ADJ',
#        u'rev_totalGross_ADJ', u'prod_budget_ADJ', u'CULT_INDEX',
#        u'is_missing_prodbudgetADJ'],
#       dtype='object')

# %%
#normalize genres
mov.genre_bomojo.value_counts()
# Out:
# Unknown               697
# Comedy                678
# Drama                 365
# Romantic Comedy       277
# Thriller              199
# Horror                195
# Comedy / Drama        191
# Action                159
# Animation             158
# Family Comedy         127
# Romance               119
# Action Comedy         115
# Crime Drama           105
# Drama / Thriller      103
# Family Adventure       89
# Period Drama           88
# Action Thriller        83
# Crime Comedy           80
# Music Drama            80
# Sports Drama           74
# Fantasy Comedy         56
# Sports Comedy          53
# Sci-Fi Action          52
# Horror Comedy          48
# Sci-Fi Horror          47
# Crime Thriller         47
# Horror Thriller        43
# Action Drama           43
# Action / Adventure     41
# Musical                41
#                      ...
# War                    36
# Romantic Thriller      35
# Fantasy                32
# Sci-Fi Comedy          31
# Period Comedy          29
# Action Horror          28
# Sci-Fi Thriller        28
# Fantasy Drama          27
# Family                 27
# Adventure              26
# Comedy Thriller        26
# Crime                  26
# War Drama              24
# Historical Drama       17
# Foreign                14
# Period Action          13
# Period Horror          11
# Historical Epic        11
# Sci-Fi                 10
# Adventure Comedy       10
# Sci-Fi Fantasy          9
# Action Fantasy          9
# Concert                 7
# Sports Action           7
# Western Comedy          6
# IMAX                    5
# Romantic Adventure      3
# War Romance             3
# Foreign / Action        2
# Foreign / Horror        2
# Name: genre_bomojo, dtype: int64

# %%
#mov=mov.loc[mov.genre_bomojo != "Documentary",:]

# %%
mov.genre_bomojo.astype('category')
genreGroups = ["Group %s" % g for g in mov.genre_bomojo.cat.categories]
len(genreGroups)
# Out:
# 64

# %%
mov['genre']=mov.genre_bomojo.str.extract(r'^(Adventure|Action|Comedy|Romance|Romantic|Fantasy|Drama|Crime|Horror|Music|Musical|Unknown|Foreign|Sci-Fi|Animation|Concert|Family|Historical|IMAX|Period|Sports|Thriller|War|Western)')

# %%
mov.genre.value_counts()
# Out:
# Comedy        895
# Unknown       697
# Action        516
# Drama         468
# Romantic      315
# Horror        286
# Crime         258
# Family        243
# Sci-Fi        215
# Thriller      199
# Period        178
# Animation     158
# Sports        134
# Music         121
# Romance       119
# Fantasy       115
# War            63
# Western        44
# Adventure      36
# Historical     28
# Foreign        18
# Concert         7
# IMAX            5
# Name: genre, dtype: int64

# %%
mov=mov[mov.genre!="IMAX"]

# %%
mov=mov[mov.genre!='Concert']

# %%
mov=mov[mov.genre!='Historical']

# %%
mov['genre']=mov.genre.str.replace(r'^Romance|Romantic','Romance')

# %%
mov.genre.value_counts()
# Out:
# Comedy       895
# Unknown      697
# Action       516
# Drama        468
# Romance      434
# Horror       286
# Crime        258
# Family       243
# Sci-Fi       215
# Thriller     199
# Period       178
# Animation    158
# Sports       134
# Music        121
# Fantasy      115
# War           63
# Western       44
# Adventure     36
# Foreign       18
# Name: genre, dtype: int64

# %%
cult = mov[mov.isCult==1]
nocultSample = mov[mov.isCult==0].sample(432)

movsample = pd.concat([cult, nocultSample])
#cult.isCult.sum()
movsample.shape
# Out:
# (864, 19)

# %%
#nocultSample.isCult.sum()
# Out:
# 0.0

# %%
plt.figure(figsize=(15, 8))
sns.set_style('whitegrid')


#sns.boxplot(x='genre',y='CULT_INDEX',data=mov.loc[~mov.genre.isin(['Foreign','Drama']),:])
sns.boxplot(x='genre',y='CULT_INDEX',data=movsample, hue='isCult')
plt.ylim(0,30)
plt.title('Variation in Cult Index by Genre')

# %%
pickle.dump(mov, open('movie_DF_0427.p', 'wb'))

# %%
mov.rating.value_counts()
# Out:
# R          2461
# PG-13      1422
# PG          994
# G           145
# Unrated      40
# NC-17        10
# GP            5
# M             1
# Name: rating, dtype: int64

# %%
mov.columns
# Out:
# Index([                u'director',              u'distributor',
#                    u'genre_bomojo',                   u'rating',
#                           u'title',              u'releaseDate',
#                          u'isCult',               u'canontitle',
#                    u'num_theaters',                u'leadActor',
#                    u'runtime_mins',              u'releaseYear',
#                 u'rev_opening_ADJ',       u'rev_totalGross_ADJ',
#                 u'prod_budget_ADJ',               u'CULT_INDEX',
#        u'is_missing_prodbudgetADJ',                    u'genre'],
#       dtype='object')

# %%
sns.regplot(x='runtime_mins',y='CULT_INDEX',data=mov)

# %%
mov.to_csv('./movie_df_apr27.csv',header=True,encoding='utf-8')

# %%
mov.sort_values(by='lifetimeRevenue', ascending=False).head(20)
# Out:
#                           director   distributor      genre_bomojo rating  \
# 4966              Steven Spielberg     Universal   Horror Thriller     PG
# 4967                Joseph Sargent     Universal   Horror Thriller     PG
# 5132              William Friedkin  Warner Bros.            Horror      R
# 5429                  Renny Harlin  Warner Bros.            Horror      R
# 5136               George Roy Hill     Universal      Crime Comedy     PG
# 3176                 James Cameron     Paramount           Romance  PG-13
# 3175              Robert Lieberman     Paramount           Romance  PG-13
# 746           Francis Ford Coppola     Paramount       Crime Drama      R
# 5114                 Arthur Hiller     Paramount           Romance     GP
# 5110                 George Seaton     Universal  Drama / Thriller      G
# 4550                 James Cameron           Fox  Sci-Fi Adventure  PG-13
# 5130                  George Lucas     Universal     Period Comedy     PG
# 5139                    Mel Brooks  Warner Bros.    Western Comedy      R
# 5148  John Guillermin, Irwin Allen           Fox   Action Thriller     PG
# 5115                 Robert Altman           Fox    Comedy / Drama      R
# 1655              Steven Spielberg     Paramount  Period Adventure     PG
# 4234              Steven Spielberg     Universal     Sci-Fi Horror  PG-13
# 1734                Randal Kleiser     Paramount           Musical     PG
# 4567                  George Lucas           Fox    Sci-Fi Fantasy     PG
# 4569                   Dave Filoni           Fox    Sci-Fi Fantasy     PG
#
#                                              title releaseDate  isCult  \
# 4966                                          Jaws  1975-06-20       0
# 4967                             Jaws: The Revenge  1975-06-20       0
# 5132                                  The Exorcist  1973-12-26       0
# 5429                       Exorcist: The Beginning  1973-12-26       0
# 5136                                     The Sting  1973-12-25       0
# 3176                                       Titanic  1997-12-19       0
# 3175                                       Titanic  1997-12-19       0
# 746                                  The Godfather  1972-03-15       0
# 5114                                    Love Story  1970-12-16       1
# 5110                                       Airport  1970-03-05       0
#       CULT_INDEX  is_missing_prodbudgetADJ    genre  lifetimeRevenue
# 4966    1.000989                         0   Horror     4.334070e+08
# 4967    1.000989                         0   Horror     4.334070e+08
# 5132    1.000375                         1   Horror     4.300233e+08
# 5429    1.000375                         1   Horror     4.300233e+08
# 5136    1.000409                         1    Crime     3.475836e+08
# 3176    1.000226                         0  Romance     3.384698e+08
# 3175    1.000226                         0  Romance     3.384698e+08
# 746     1.000443                         0    Crime     2.929037e+08
# 5114    1.000364                         1  Romance     2.897404e+08
# 5110    1.000395                         0    Drama     2.736517e+08
# 4550    1.000164                         1   Sci-Fi     2.727738e+08
# 5130    1.000408                         1   Period     2.562315e+08
# 5139    1.000345                         1  Western     2.416290e+08
# 5148    1.000333                         0   Action     2.345520e+08
# 5115    1.000348                         0   Comedy     2.222128e+08
# 1655    1.000583                         0   Period     2.176966e+08
# 4234    1.000239                         0   Sci-Fi     2.131748e+08
# 1734    1.000720                         0    Music     2.131136e+08
# 4567    1.000190                         0   Sci-Fi     2.115588e+08
# 4569    1.000190                         0   Sci-Fi     2.115588e+08

# %%
# trying a new approach to CULT_INDEX: Break down the total gross over the # of years. Here's how CI looks:
# ( total lifetime gross / time ) * ln(time). I want to add a weighting factor in favor of older movies so that I don't skew recent movies that result in 
# higher average gross.

mov['lifetimeRevenue'] = (mov.rev_totalGross_ADJ/(2016-mov.releaseYear)) * np.log(2016-mov.releaseYear)

mov['CULT_INDEX'] = mov.lifetimeRevenue/((mov.rev_opening_ADJ)*(mov.num_theaters)) #get it greater than 1
mov=mov.sort_values(by='CULT_INDEX',ascending=False)

# %%
mov.head(50)
# Out:
#                          director             distributor      genre_bomojo  \
# 3                     Peter Yates                     Fox    Comedy / Drama
# 1                 Peter Masterson         Island Pictures             Drama
# 56           Francis Ford Coppola                     MGM               War
# 26                Martin Scorsese            Warner Bros.           Unknown
# 13                  Albert Brooks                Columbia   Romantic Comedy
# 23                   Will Carroll                 Miramax           Romance
# 42                 Vadim Perelman              DreamWorks  Drama / Thriller
# 32                   Miranda July                     IFC    Comedy / Drama
# 40             Raymond De Felitta        Anchor Bay Films            Comedy
# 87                      Bob Fosse                     Fox           Musical
# 66                      Mira Nair               USA Films           Foreign
# 49                      Ed Harris           Sony Classics             Drama
# 84                Kimberly Peirce         Fox Searchlight             Drama
# 82                        Ang Lee          Focus Features           Foreign
# 137              Kevin Tancharoen                     MGM       Music Drama
# 138                   Alan Parker                     MGM       Music Drama
# 21                 Gavin O'Connor                 Miramax             Drama
# 75                Bruce Beresford               Universal           Unknown
# 113                   Woody Allen         Fox Searchlight    Fantasy Comedy
# 119                  Sidney Lumet               ThinkFilm    Crime Thriller
# 41   Fenton Bailey, Randy Barbato                  Strand   Comedy Thriller
# 120                  Sidney Lumet            Warner Bros.           Unknown
# 29                 Matthew Barney                    Palm           Unknown
# 155             Richard Linklater         Millennium Ent.    Comedy / Drama
# 52                   Julie Taymor         Fox Searchlight     Fantasy Drama
# 212                   Ken Russell            Warner Bros.     Sci-Fi Horror
# 180    PG-13                                      Get Low  2010-07-30       0
# 112        R                                     Sunshine  1999-12-17       0
# 169    PG-13            The Diving Bell and the Butterfly  2007-11-30       0
# 53     PG-13  Amandla!: A Revolution in Four-Part Harmony  2003-02-19       0
# 150  Unrated                          Requiem for a Dream  2000-10-06       1
# 57         R                                         Spun  2003-03-14       0
# 143        R                                  Half Nelson  2006-08-11       0
# 106        R                                   The Future  2011-07-29       0
# 77         R                                   Compliance  2012-08-17       0
# 287    PG-13                  Beasts of the Southern Wild  2012-06-27       0
# 209        R                                    25th Hour  2002-12-19       0
# 135    PG-13                               Beyond the Sea  2004-12-17       0
# 144    NC-17                                   Killer Joe  2012-07-27       0
# 204        R                                Winter's Bone  2010-06-11       1
# 134        R                                      Perfume  2006-12-27       0
# 133        R             Perfume: The Story of a Murderer  2006-12-27       0
#
#                        canontitle  num_theaters  \
# 3                    breakingaway             1
# 1                 triptobountiful             1
# 56                  apocalypsenow             3
# 26                     afterhours             1
# 13                  modernromance             1
# 23                 playingbyheart             1
# 42              houseofsandandfog             2
# 32      meandyouandeveryoneweknow             1
# 40                     cityisland             2
# 87                    allthatjazz             5
# 66                 monsoonwedding             2
# 49                        pollock             2
# 84                    boysdontcry             2
# 82                    lustcaution             1
# 137                          fame             3
# 138                          fame             3
# 21                        miracle             1
# 75                  tendermercies             3
# 113             melindaandmelinda             1
# 119  beforethedevilknowsyouredead             2
# 41                   partymonster             1
# 120               princeofthecity             3
# 29                 cremastercycle             1
# 155                        bernie             3
# 52                          titus             2
# 212                 alteredstates             3
# 141               sleepwalkwithme             1
# 107                   paintedveil             4
# 47                 mysteriousskin             1
# 211             motorcyclediaries             3
# 94                       jesusson             1
# 81                        control             1
# 130                  stationagent             3
# 221                    hurtlocker             4
# 180                        getlow             4
# 112                      sunshine             4
# 169     divingbellandthebutterfly             3
# 53                        amandla             1
# 150              requiemforadream             2
# 57                           spun             1
# 143                    halfnelson             2
# 106                        future             1
# 77                     compliance             1
# 287       beastsofthesouthernwild             4
# 209                      25thhour             5
# 135                  beyondthesea             6
# 144                     killerjoe             3
# 204                   wintersbone             4
# 134                       perfume             3
# 133                       perfume             3
#
#                                              leadActor  runtime_mins  \
# 3                                   Dennis Christopher           100
# 1                                       Geraldine Page           108
# 56                                        Martin Sheen           153
# 26                                       Griffin Dunne            96
# 13                                       Albert Brooks            93
# 23                                      Angelina Jolie           121
# 42                                   Jennifer Connelly           126
# 32                                        Miranda July            90
# 40                                         Andy García           100
# 87                                        Roy Scheider           123
# 66                                    Naseeruddin Shah           114
# 49                                           Ed Harris           117
# 84                                        Hilary Swank           118
# 82                                 Tony Leung Chiu-Wai           158
# 137                                       Debbie Allen           134
# 138                                         Irene Cara           134
# 21                                        Kurt Russell            96
# 75                                       Robert Duvall            92
# 113                                   Chiwetel Ejiofor           100
# 119                             Philip Seymour Hoffman           123
# 41                                          Seth Green            97
# 120                                     Treat Williams           167
# 29                                                 NaN           182
# 155                                         Jack Black           104
# 135    6.667279                         1     Music   2505811.418421
# 144    6.580510                         1    Comedy    812606.407458
# 204    6.325484                         0     Drama   2360081.273623
# 134    6.074871                         0  Thriller    891990.546650
# 133    6.074871                         0  Thriller    891990.546650

# %%
plt.figure(figsize=(15, 8))
sns.set_style('whitegrid')

#sns.boxplot(x='genre',y='CULT_INDEX',data=mov.loc[~mov.genre.isin(['Foreign','Drama']),:])
sns.boxplot(x='isCult',y='CULT_INDEX',data=movsample)
plt.ylim(0,0.009)
plt.title('Variation in Cult Index')

# %%
plt.figure(figsize=(15, 8))
sns.set_style('whitegrid')

#sns.boxplot(x='genre',y='CULT_INDEX',data=mov.loc[~mov.genre.isin(['Foreign','Drama']),:])
sns.boxplot(x='rating',y='CULT_INDEX',data=movsample.loc[~movsample.rating.isin(['Unrated']),:], hue='isCult')
plt.ylim(0,0.02)
plt.title('Variation in Cult Index by Rating\n(EXCLUDING "Unrated")')

# %%
movsample.columns
# Out:
# Index([                u'director',              u'distributor',
#                    u'genre_bomojo',                   u'rating',
#                           u'title',              u'releaseDate',
#                          u'isCult',               u'canontitle',
#                    u'num_theaters',                u'leadActor',
#                    u'runtime_mins',              u'releaseYear',
#                 u'rev_opening_ADJ',       u'rev_totalGross_ADJ',
#                 u'prod_budget_ADJ',               u'CULT_INDEX',
#        u'is_missing_prodbudgetADJ',                    u'genre',
#                 u'lifetimeRevenue'],
#       dtype='object')

# %%
#SWITCHING TO CHECK OUT THE NUMERIC FEATURES
mov.to_csv('./movie_df_apr28.csv',header=True,encoding='utf-8')
pickle.dump(mov, open('movie_DF_0428.p', 'wb'))

# %%
#BACK TO CATEGORICALS
with open(r"movie_DF_0427.p", "rb") as input_file:
    mov = pickle.load(input_file)

# %%
mov=mov[mov.runtime_mins.notnull()]

# %%
mov.head()
# Out:
#            director      distributor     genre_bomojo rating  \
# 1   Peter Masterson  Island Pictures            Drama     PG
# 3       Peter Yates              Fox   Comedy / Drama     PG
# 13    Albert Brooks         Columbia  Romantic Comedy      R
# 26  Martin Scorsese     Warner Bros.          Unknown      R
# 23     Will Carroll          Miramax          Romance      R
#
#                     title releaseDate  isCult       canontitle  num_theaters  \
# 1   The Trip to Bountiful  1985-12-20       0  triptobountiful             1
# 3           Breaking Away  1979-07-13       0     breakingaway             1
# 13         Modern Romance  1981-03-13       0    modernromance             1
# 26            After Hours  1985-09-13       1       afterhours             1
# 23       Playing by Heart  1999-01-01       0   playingbyheart             1
#
#              leadActor  runtime_mins  releaseYear  rev_opening_ADJ  \
# 1       Geraldine Page           108         1985     20560.131429
# 3   Dennis Christopher           100         1979     60753.264000
# 13       Albert Brooks            93         1981     57915.000000
# 26       Griffin Dunne            96         1985    111380.657143
# 23      Angelina Jolie           121         1999     45764.004000
#
#     rev_totalGross_ADJ  prod_budget_ADJ  CULT_INDEX  is_missing_prodbudgetADJ  \
# 1         4.502261e+07   5650869.561865    1.558343                         1
# 3         1.934629e+08  24281886.199245    1.541993                         1
# 13        2.891783e+07   3629530.152339    1.479403                         1
# 26        6.375674e+07  61933085.501859    1.471978                         1
# 23        1.169051e+07  28571428.571429    1.461017                         0
#
#        genre
# 1      Drama
# 3     Comedy
# 13  Romantic
# 26   Unknown
# 23   Romance

# %%
len(mov.director.unique())
# Out:
# 2150

# %%
#get representative sample from noncult labels to compare
cult = mov[mov.isCult==1]
nocultSample = mov[mov.isCult==0].sample(432)

movsample = pd.concat([cult, nocultSample])
#cult.isCult.sum()
movsample.shape
# Out:
# (870, 18)

# %%
len(cult.director.unique())
# Out:
# 332

# %%
cult.director.value_counts()
# Out:
# David Lynch                           5
# David Cronenberg                      4
# Walter Hill                           4
# Joel Coen                             4
# Martin Scorsese                       3
# Jim Jarmusch                          3
# Michael Lehmann                       3
# Trey Parker                           3
# Stanley Kubrick                       3
# Kathryn Bigelow                       3
# John Waters                           3
# Ridley Scott                          3
# Mel Brooks                            3
# Darren Aronofsky                      3
# John Hughes                           3
# Jonathan Demme                        3
# Brian De Palma                        3
# Wes Anderson                          3
# Paul Verhoeven                        3
# Steven Soderbergh                     3
# Quentin Tarantino                     3
# Abel Ferrara                          3
# Wes Craven                            3
# Tony Scott                            3
# John Carpenter                        3
# Terry Gilliam                         3
# Tim Burton                            3
# Neil LaBute                           3
# Ben Stiller                           3
# Jeannot Szwarc                        2
#                                      ..
# Bruce W. Timm                         1
# Antonia Bird                          1
# Anthony Abrams, Adam Larson Broder    1
# Craig Gillespie                       1
# Gary Trousdale, Kirk Wise             1
# William Friedkin                      1
# Albert Magnoli                        1
# Mark Jones                            1
# Louis C.K.                            1
# Jules Bass, Arthur Rankin, Jr.        1
# Shane Carruth                         1
# Daniel Mann                           1
# Arthur Hiller                         1
# Robert Harmon                         1
# Shane Black                           1
# Andy and Larry Wachowski              1
# Akiva Schaffer                        1
# Adrian Lyne                           1
# Jack Sholder                          1
# David Wain                            1
# Adam McKay                            1
# Neil Jordan                           1
# Bobcat Goldthwait                     1
# William Lustig                        1
# Brad Anderson                         1
# Terrence Malick                       1
# Peter Segal                           1
# Glenn Gordon Caron                    1
# John Woo                              1
# Newt Arnold                           1
# Name: director, dtype: int64

# %%
mov.to_csv('./movie_df_apr28.csv',header=True,encoding='utf-8')

# %%
mov = pd.read_csv('./movie_df_apr28.csv',header=0,encoding='utf-8')

# %%
mov.head()
# Out:
#    Unnamed: 0         director      distributor     genre_bomojo rating  \
# 0           1  Peter Masterson  Island Pictures            Drama     PG
# 1           3      Peter Yates              Fox   Comedy / Drama     PG
# 2          13    Albert Brooks         Columbia  Romantic Comedy      R
# 3          26  Martin Scorsese     Warner Bros.          Unknown      R
# 4          23     Will Carroll          Miramax          Romance      R
#
#                    title releaseDate  isCult       canontitle  num_theaters  \
# 0  The Trip to Bountiful  1985-12-20       0  triptobountiful             1
# 1          Breaking Away  1979-07-13       0     breakingaway             1
# 2         Modern Romance  1981-03-13       0    modernromance             1
# 3            After Hours  1985-09-13       1       afterhours             1
# 4       Playing by Heart  1999-01-01       0   playingbyheart             1
#
#             leadActor  runtime_mins  releaseYear  rev_opening_ADJ  \
# 0      Geraldine Page           108         1985     20560.131429
# 1  Dennis Christopher           100         1979     60753.264000
# 2       Albert Brooks            93         1981     57915.000000
# 3       Griffin Dunne            96         1985    111380.657143
# 4      Angelina Jolie           121         1999     45764.004000
#
#    rev_totalGross_ADJ  prod_budget_ADJ  CULT_INDEX  is_missing_prodbudgetADJ  \
# 0        4.502261e+07    5650869.56187    1.558343                         1
# 1        1.934629e+08   24281886.19920    1.541993                         1
# 2        2.891783e+07    3629530.15234    1.479403                         1
# 3        6.375674e+07   61933085.50190    1.471978                         1
# 4        1.169051e+07   28571428.57140    1.461017                         0
#
#       genre
# 0     Drama
# 1    Comedy
# 2  Romantic
# 3   Unknown
# 4   Romance

# %%
mov.drop(['Unnamed: 0'],axis=1,inplace=True)

# %%
pickle.dump(mov, open('movie_DF_0428.p', 'wb'))

# %%
cult_dirs=cult.groupby(['director','distributor'], sort=True).size().reset_index()

# %%
cult.groupby(['director','distributor','genre']).size().sort_values(ascending=False).head(20).plot(kind='bar', figsize=(15,5), title='Director, Studio, and Genre Interaction\n to Produce Cult Phenom')

# %%
cult.groupby(['director','distributor']).size().sort_values(ascending=False).head(20).plot(kind='bar', figsize=(15,5), title='Director and Studio Interaction\n to Produce Cult Phenom')

# %%
cult.groupby(['director','genre']).size().sort_values(ascending=False).head(29).plot(kind='bar', figsize=(15,5), title='Director and Genre Interaction\n to Produce Cult Phenom')

# %%
cult.groupby(['director']).size().sort_values(ascending=False).head(72).plot(kind='bar', figsize=(15,5),title='Directors that Produce Cult Phenom')

# %%
list(cult.groupby(['director']).size().sort_values(ascending=False).reset_index().iloc[4:71,0])
# Out:
# [u'Tim Burton',
#  u'Ridley Scott',
#  u'Terry Gilliam',
#  u'Steven Soderbergh',
#  u'Michael Lehmann',
#  u'Paul Verhoeven',
#  u'Mel Brooks',
#  u'Ben Stiller',
#  u'Martin Scorsese',
#  u'Quentin Tarantino',
#  u'Tony Scott',
#  u'Neil LaBute',
#  u'Trey Parker',
#  u'Kathryn Bigelow',
#  u'John Hughes',
#  u'Darren Aronofsky',
#  u'Abel Ferrara',
#  u'John Carpenter',
#  u'Wes Craven',
#  u'Jonathan Demme',
#  u'Wes Anderson',
#  u'Brian De Palma',
#  u'Jim Jarmusch',
#  u'John Waters',
#  u'Peter Bogdanovich',
#  u'Paul W. S. Anderson',
#  u'Doug Liman',
#  u'Rob Zombie',
#  u'Richard Linklater',
#  u'Oliver Stone',
#  u'Francis Ford Coppola',
#  u'Nicole Holofcener',
#  u'Frank Oz',
#  u'Zack Snyder',
#  u'George A. Romero',
#  u'George Armitage',
#  u'John Cameron Mitchell',
#  u'Joe Dante',
#  u'John Dahl',
#  u'John Milius',
#  u'Jeannot Szwarc',
#  u'James Foley',
#  u'Kenny Ortega',
#  u'Kevin Smith',
#  u'Lawrence Kasdan',
#  u'Harold Ramis',
#  u'Mark L. Lester',
#  u'Matthew Robbins',
#  u'Glen Morgan',
#  u'Danny DeVito',
#  u'Michael Mann',
#  u'Michael Ritchie',
#  u'Mike Judge',
#  u'Robert Rodriguez',
#  u'Joel Schumacher',
#  u'Ate de Jong',
#  u'Todd Haynes',
#  u'Sidney Lumet',
#  u'Todd Solondz',
#  u'Vincent Gallo',
#  u'Alex Proyas',
#  u'Allan Moyle',
#  u'Stanley Kubrick',
#  u'Tom Holland',
#  u'Terry Zwigoff',
#  u'Woody Allen',
#  u'Tom DiCillo',
#  u'Hugh Wilson']

# %%
cult.groupby(['distributor']).size().sort_values(ascending=False).head(50).plot(kind='bar', figsize=(15,5),title='Studios that Produce Cult Phenoms')

# %%
cult.groupby(['genre']).size().sort_values(ascending=False).head(50).plot(kind='bar', figsize=(15,5),title='Genres that Produce Cult Phenoms')

# %%
cult[cult.distributor=='Universal']
# Out:
#                           director distributor      genre_bomojo rating  \
# 896                    David Lynch   Universal  Drama / Thriller      R
# 1173              Robert Greenwald   Universal           Musical     PG
# 1317              Steven Spielberg   Universal     Period Comedy     PG
# 1285                Jeannot Szwarc   Universal           Romance     PG
# 1548                   John Landis   Universal            Comedy      R
# 5230                  Sidney Lumet   Universal           Musical      G
# 1704              David Cronenberg   Universal     Sci-Fi Horror      R
# 1711                John Carpenter   Universal     Sci-Fi Horror      R
# 1712  Matthijs van Heijningen, Jr.   Universal     Sci-Fi Horror      R
# 2257                   David Lynch   Universal    Sci-Fi Fantasy  PG-13
# 1773                Brian De Palma   Universal       Crime Drama      R
# 1893                   John Hughes   Universal    Comedy / Drama      R
# 2223                Joseph Sargent   Universal           Unknown      R
# 2697               Joel Schumacher   Universal    Action / Crime      R
# 2696                   Walter Hill   Universal    Action / Crime      R
# 1679                  Todd Holland   Universal  Family Adventure     PG
# 2311                   John Hughes   Universal     Sci-Fi Comedy  PG-13
# 2081                   Walter Hill   Universal           Unknown     PG
# 2332               Michael Ritchie   Universal            Comedy     PG
# 2438                  Ridley Scott   Universal           Fantasy     PG
# 572                  Terry Gilliam   Universal           Unknown      R
# 2412                      Ted Post   Universal           Musical     PG
# 2548                   Nick Castle   Universal  Sci-Fi Adventure     PG
# 598           Francis Ford Coppola   Universal           Unknown      R
# 2729                   Jesse Dylan   Universal            Comedy      R
# 3090                   John Milius   Universal    Action Fantasy      R
# 3091                 Marcus Nispel   Universal    Action Fantasy      R
# 2348                 Ron Underwood   Universal     Horror Comedy  PG-13
# 2681                 George Miller   Universal            Family      G
# 2867                 Willard Huyck   Universal     Sci-Fi Comedy     PG
# 5193               George Roy Hill   Universal     Sports Comedy      R
# 2208                   Mike Hodges   Universal  Sci-Fi Adventure     PG
# 3044                 Peter Jackson   Universal     Horror Comedy      R
# 1356                   5 directors   Universal           Unknown      R
# 2775                   Ben Stiller   Universal   Romantic Comedy  PG-13
# 2638                 Terry Gilliam   Universal            Comedy      R
# 3520                   Tamra Davis   Universal            Comedy      R
# 3131                     Sam Raimi   Universal     Action Horror      R
# 4274                      Mamma Mia!  2008-07-18       1
# 4541           Kicking and Screaming  2005-05-13       1
#
#                      canontitle  num_theaters                leadActor  \
# 896             mulhollanddrive     66.000000              Naomi Watts
# 1173                     xanadu    249.000000       Olivia Newton-John
# 1317                       1941    325.000000             John Belushi
# 1285            somewhereintime    369.000000        Christopher Reeve
# 1548              bluesbrothers    594.000000              Dan Aykroyd
# 5230                        wiz    640.000000               Diana Ross
# 1704                 videodrome    600.000000              James Woods
# 1711                      thing    840.000000             Kurt Russell
# 1712                      thing    840.000000  Mary Elizabeth Winstead
# 2257                       dune    915.000000          Kyle MacLachlan
# 1773                   scarface    996.000000                Al Pacino
# 1893              breakfastclub   1071.000000           Emilio Estevez
# 2223                 nightmares   1025.000000          Lance Henriksen
# 2697                   trespass   1022.000000             Nicolas Cage
# 2696                   trespass   1022.000000              Bill Paxton
# 1679                     wizard   1155.000000              Fred Savage
# 2311               weirdscience   1158.000000     Anthony Michael Hall
# 2081              streetsoffire   1150.000000             Michael Paré
# 2332                     fletch   1225.000000              Chevy Chase
# 2438                     legend   1187.000000               Tom Cruise
# 572                      brazil   1740.000000           Jonathan Pryce
# 2412                       baby   1229.000000          Anjanette Comer
# 2548            laststarfighter   1287.000000              Lance Guest
# 598                  rumblefish   1740.000000              Matt Dillon
# 2729                    howhigh   1266.000000               Method Man
# 3090          conanthebarbarian   1395.000000    Arnold Schwarzenegger
# 3091          conanthebarbarian   1395.000000              Jason Momoa
# 2348                    tremors   1472.000000              Kevin Bacon
# 2681                       babe   1591.000000           James Cromwell
# 2867              howardtheduck   1554.000000             Lea Thompson
# 5193                   slapshot   1698.043732              Paul Newman
# 2208                flashgordon   1740.000000           Timothy Dalton
# 3044                frighteners   1669.000000           Michael J. Fox
# 1356       amazonwomenonthemoon   1740.000000             Arsenio Hall
# 2775               realitybites   1740.000000             Winona Ryder
# 2638  fearandloathinginlasvegas   1740.000000              Johnny Depp
# 3520                  halfbaked   1701.000000           Dave Chappelle
# 3131                    darkman   1786.000000              Liam Neeson
# 2835       peopleunderthestairs   1850.000000           Everett McGill
# 3566                 hardtarget   1972.000000    Jean-Claude Van Damme
# 3208               happygilmore   2022.000000             Adam Sandler
# 3199                    slither   1945.000000           Nathan Fillion
# 3200                    slither   1945.000000               James Caan
# 3672                 mysterymen   2136.000000              Ben Stiller
# 4040                 waterworld   2268.000000            Kevin Costner
# 3831                   serenity   2188.000000           Nathan Fillion
# 3383                  macgruber   2551.000000               Will Forte
# 4613              dawnofthedead   2745.000000             Sarah Polley
# 4612              dawnofthedead   2745.000000               David Emge
# 4123                       paul   2802.000000               Simon Pegg
# 4274                   mammamia   2976.000000             Meryl Streep
# 4541        kickingandscreaming   3455.000000            Josh Hamilton
#
#       runtime_mins  releaseYear  rev_opening_ADJ  rev_totalGross_ADJ  \
# 896            147         2001    900273.353571        1.694924e+07
# 1173            96         1980   4856263.500000        2.478844e+08
# 1317           118         1979   9272913.936000        3.740389e+08
# 1773     4.294769e+07    1.000603                         1     Crime
# 1893     3.460194e+07    1.000555                         1    Comedy
# 2223     2.389558e+07    1.000548                         1   Unknown
# 2697     7.282672e+06    1.000541                         1    Action
# 2696     7.282672e+06    1.000541                         1    Action
# 1679     8.674096e+06    1.000508                         1    Family
# 2311     1.797713e+07    1.000497                         1    Sci-Fi
# 2081     6.863424e+06    1.000494                         1   Unknown
# 2332     3.817542e+07    1.000478                         1    Comedy
# 2438     1.046275e+07    1.000477                         1   Fantasy
# 572      7.489185e+06    1.000459                         1   Unknown
# 2412     4.329848e+06    1.000452                         1     Music
# 2548     2.437901e+07    1.000447                         1    Sci-Fi
# 598      2.389558e+07    1.000443                         0   Unknown
# 2729     2.687747e+07    1.000441                         0    Comedy
# 3090     4.346893e+07    1.000410                         1    Action
# 3091     4.346893e+07    1.000410                         1    Action
# 2348     8.730104e+06    1.000387                         1    Horror
# 2681     3.181127e+07    1.000365                         1    Family
# 2867     8.034672e+07    1.000361                         0    Sci-Fi
# 5193     5.345294e+07    1.000353                         1    Sports
# 2208     3.705178e+07    1.000342                         1    Sci-Fi
# 3044     7.998458e+06    1.000332                         1    Horror
# 1356     3.333195e+05    1.000331                         1   Unknown
# 2775     1.153318e+07    1.000325                         1  Romantic
# 2638     2.701227e+08    1.000320                         0    Comedy
# 3520     2.701227e+08    1.000319                         1    Comedy
# 3131     1.774532e+07    1.000316                         1    Action
# 2835     1.048458e+07    1.000307                         0    Horror
# 3566     1.791309e+07    1.000282                         1    Action
# 3208     1.820268e+07    1.000280                         0    Sports
# 3199     1.770833e+07    1.000273                         0    Sci-Fi
# 3200     1.770833e+07    1.000273                         0    Sci-Fi
# 3672     9.714286e+07    1.000257                         0   Fantasy
# 4040     2.732940e+08    1.000247                         0    Sci-Fi
# 3831     4.752688e+07    1.000245                         0    Sci-Fi
# 3383     1.091463e+07    1.000207                         0    Comedy
# 4613     3.275807e+07    1.000194                         0    Horror
# 4612     3.275807e+07    1.000194                         0    Horror
# 4123     4.232259e+07    1.000191                         0    Sci-Fi
# 4274     5.748178e+07    1.000186                         0     Music
# 4541     5.483871e+07    1.000155                         0    Sports

# %%
#SUGGESTED GROUPING BUCKETS ARE 
#Director: SEASONED (>3), INTERMEDIATES>1, NOVICES==1, OTHER
#Genre: as is
#Distributor: SEASONED(>30), INTERMEDIATES>5, NOVICES>1, OTHER

#Group DIrectors
mov['directorTier']=mov['director']
mov.directorTier.replace(list(cult.groupby(['director']).size().sort_values(ascending=False).head(4).reset_index().iloc[:,0]), 'SEASONED', inplace=True)
mov.directorTier.replace(list(cult.groupby(['director']).size().sort_values(ascending=False).reset_index().iloc[4:71,0]), 'INTERMEDIATE', inplace=True)
mov.directorTier.replace(list(cult.groupby(['director']).size().sort_values(ascending=False).reset_index().iloc[72:cult.shape[0],0]), 'NOVICE', inplace=True)

# %%
mov['directorTier']=mov.directorTier.str.replace(r'.*[^SEASONED|INTERMEDIATE|NOVICE].*','OTHER')

# %%
mov.directorTier.value_counts()
# Out:
# OTHER           3603
# NOVICE           863
# INTERMEDIATE     542
# SEASONED          35
# Name: directorTier, dtype: int64

# %%
#mov=mov[mov.directorTier.isin(['OTHER','SEASONED','NOVICE','INTERMEDIATE'])]

# %%
pickle.dump(mov, open('movie_DF_0428_1.p', 'wb'))

# %%
#WHEW, do teh same thing for STUDIOS (DISTRIBUTORS)
# Out:
# OTHER           3603
# NOVICE           863
# INTERMEDIATE     542
# SEASONED          35
# Name: directorTier, dtype: int64

# %%
mov['studioTier']=mov['distributor']
mov.studioTier.replace(list(cult.groupby(['distributor']).size().sort_values(ascending=False).head(4).reset_index().iloc[:,0]), 'SEASONED', inplace=True)
mov.studioTier.replace(list(cult.groupby(['distributor']).size().sort_values(ascending=False).reset_index().iloc[4:26,0]), 'INTERMEDIATE', inplace=True)
mov.studioTier.replace(list(cult.groupby(['distributor']).size().sort_values(ascending=False).reset_index().iloc[27:cult.shape[0],0]), 'NOVICE', inplace=True)

# %%
mov['studioTier']=mov.studioTier.str.replace(r'.*[^SEASONED|INTERMEDIATE|NOVICE].*','OTHER')

# %%
mov.studioTier.value_counts()
# Out:
# INTERMEDIATE    2239
# SEASONED        1881
# NOVICE           539
# OTHER            411
# Name: studioTier, dtype: int64

# %%
mov.head()
# Out:
#           director      distributor     genre_bomojo rating  \
# 0  Peter Masterson  Island Pictures            Drama     PG
# 1      Peter Yates              Fox   Comedy / Drama     PG
# 2    Albert Brooks         Columbia  Romantic Comedy      R
# 3  Martin Scorsese     Warner Bros.          Unknown      R
# 4     Will Carroll          Miramax          Romance      R
#
#                    title releaseDate  isCult       canontitle  num_theaters  \
# 0  The Trip to Bountiful  1985-12-20       0  triptobountiful             1
# 1          Breaking Away  1979-07-13       0     breakingaway             1
# 2         Modern Romance  1981-03-13       0    modernromance             1
# 3            After Hours  1985-09-13       1       afterhours             1
# 4       Playing by Heart  1999-01-01       0   playingbyheart             1
#
#             leadActor  runtime_mins  releaseYear  rev_opening_ADJ  \
# 0      Geraldine Page           108         1985     20560.131429
# 1  Dennis Christopher           100         1979     60753.264000
# 2       Albert Brooks            93         1981     57915.000000
# 3       Griffin Dunne            96         1985    111380.657143
# 4      Angelina Jolie           121         1999     45764.004000
#
#    rev_totalGross_ADJ  prod_budget_ADJ  CULT_INDEX  is_missing_prodbudgetADJ  \
# 0        4.502261e+07    5650869.56187    1.558343                         1
# 1        1.934629e+08   24281886.19920    1.541993                         1
# 2        2.891783e+07    3629530.15234    1.479403                         1
# 3        6.375674e+07   61933085.50190    1.471978                         1
# 4        1.169051e+07   28571428.57140    1.461017                         0
#
#       genre  directorTier    studioTier
# 0     Drama         OTHER        NOVICE
# 1    Comedy         OTHER      SEASONED
# 2  Romantic         OTHER  INTERMEDIATE
# 3   Unknown  INTERMEDIATE      SEASONED
# 4   Romance         OTHER  INTERMEDIATE

# %%
pickle.dump(mov, open('movie_DF_0428.p', 'wb'))
